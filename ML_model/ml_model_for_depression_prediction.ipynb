# %%
import pandas as pd
import numpy
# Load the dataset to inspect its structure and contents
file_path = 'C:/Users/eashw/Downloads/Mental_health_Depression_disorder_Data.xlsx'
data = pd.read_excel(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head()
# Out:
#         Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0  Afghanistan  AFG  1990           0.160560              0.697779
# 1  Afghanistan  AFG  1991           0.160312              0.697961
# 2  Afghanistan  AFG  1992           0.160135              0.698107
# 3  Afghanistan  AFG  1993           0.160037              0.698257
# 4  Afghanistan  AFG  1994           0.160022              0.698469
#
#    Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0              0.101855               4.828830                1.677082
# 1              0.099313               4.829740                1.684746
# 2              0.096692               4.831108                1.694334
# 3              0.094336               4.830864                1.705320
# 4              0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)  ...  10-14 years old (%)  \
# 0        4.071831                   0.672404  ...             1.594676
# 1        4.079531                   0.671768  ...             1.588356
# 2        4.088358                   0.670644  ...             1.577980
# 3        4.096190                   0.669738  ...             1.577201
# 4        4.099582                   0.669260  ...             1.570846
#
#    All ages (%)  70+ years old (%)  30-34 years old (%)  15-19 years old (%)  \
# 0      3.218871           5.202803             5.799034             3.455708
# 1      3.203468           5.192849             5.814828             3.451880
# 2      3.156559           5.176872             5.829745             3.434982
# 3      3.120655           5.167355             5.853060             3.420210
# 4      3.082179           5.157549             5.852851             3.425222
#
#    25-29 years old (%)  50-69 years old (%)  Age-standardized (%)  \
# 0             5.175856             5.917752              4.071831
# 1             5.176729             5.927093              4.079531
# 2             5.160249             5.945656              4.088358
# 3             5.148767             5.966915              4.096190
# 4             5.148227             5.975907              4.099582
#
#    15-49 years old (%)  \
# 0             4.939766
# 1             4.902682
# 2             4.837097
# 3             4.813657
# 4             4.839340
#
#    Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number) (people suffering from depression)
# 0                                      318435.813670
# 1                                      329044.773956
# 2                                      382544.572895
# 3                                      440381.507393
# 4                                      456916.645489
#
# [5 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# Handling missing values - if any, we will fill them with the mean of the column
imputer = SimpleImputer(strategy='mean')
data_imputed = imputer.fit_transform(data.select_dtypes(include=['float64', 'int64']))

# Normalizing the numerical features
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_imputed)

# Convert the scaled array back to a dataframe
data_preprocessed = pd.DataFrame(data_scaled, columns=data.select_dtypes(include=['float64', 'int64']).columns)

# Define the target variable and features
target = 'Depression (%)'
features = data_preprocessed.drop(columns=[target]).columns

# Splitting the dataset into training(80%) and test sets(20%)
X_train, X_test, y_train, y_test = train_test_split(data_preprocessed[features], data_preprocessed[target], test_size=0.1, random_state=13)

np_y_train = y_train.to_numpy().ravel(); np_y_test = y_test.to_numpy().ravel()


print(X_train)
print(np_y_train)
# Preview the preprocessed feature data
X_train.head(), y_train.head()
# Out:
#           Year  Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
# 6210  1.052274           0.073756             -1.703580             -0.856203
# 2054 -0.433289           1.061089              1.479617              1.822938
# 5736  1.299867           0.480834             -1.033922             -0.453273
# 1875  1.671258           1.228565              2.260584              1.978979
# 3471  1.671258          -1.290661             -0.658480             -0.883133
# ...        ...                ...                   ...                   ...
# 866   1.547461          -1.068587             -0.569047             -0.810017
# 2790  0.557086           2.522772              0.484480              1.731024
# 74    0.557086          -0.342112              0.551677             -0.249996
# 6320  0.804680           1.099680              1.306423              2.077004
# 338  -1.423664           1.004454              1.320094              1.968221
#
#       Anxiety disorders (%)  Drug use disorders (%)  \
# 6210              -0.664086               -0.400982
# 2054               2.370975                0.435030
# 5736              -0.572057               -0.128744
# 1875               0.466843                1.733763
# 3471              -0.281801               -0.766524
# ...                     ...                     ...
# 866               -0.936167               -0.917591
# 2790               1.534911                0.488050
# 74                 0.893654                1.658987
# 6320               1.484509                0.681478
# 338                1.170490               -0.141755
#
#       Alcohol use disorders (%)  20-24 years old (%)  10-14 years old (%)  \
# 6210                  -0.439776            -0.296644            -0.811821
# 2054                  -0.211459             1.233507             1.519230
# 5736                  -0.815803            -1.066898            -0.616607
# 1875                   0.239821             0.855871             0.950462
# 3471                   0.022277            -0.569719             0.066822
# ...                         ...                  ...                  ...
# 866                   -0.682212            -0.453609            -0.500258
# 2790                   0.558441             1.419879             1.545106
# 74                    -1.077430             0.029738             0.877191
# 6320                  -0.182381             0.660651             1.216506
# 338                    0.157323             0.484148            -0.031202
#
#       All ages (%)  70+ years old (%)  30-34 years old (%)  \
# 6210     -0.833572          -0.103029            -0.721169
# 2054      1.818524          -0.606332             1.525181
# 5736      0.471623           0.040691            -1.022095
# 1875      1.552777          -0.665968             1.293444
# 3471     -0.874479           0.978135            -0.469588
# ...            ...                ...                  ...
# 866      -0.851757           1.295490             0.140308
# 2790      1.691200          -0.570394             1.470674
# 74        0.278782          -0.846526             0.521875
# 6320      1.438321          -0.582781             0.791238
# 338       0.961610          -0.734680             0.627699
#
#       15-19 years old (%)  25-29 years old (%)  50-69 years old (%)  \
# 6210            -0.452162            -0.575913             0.136964
# 2054             0.990451             1.389302            -0.093999
# 5736            -0.779095            -1.131032             0.323636
# 1875             0.752761             1.150112            -0.232764
# 3471            -0.171268            -0.524436             0.633046
# ...                   ...                  ...                  ...
# 866             -0.520729            -0.119690             0.986999
# 2790             1.130750             1.486863             0.025566
# 74               0.339622             0.305151            -0.268673
# 6320             0.601712             0.747803            -0.407399
# 338              0.011384             0.584720            -0.766602
#
#       Age-standardized (%)  15-49 years old (%)  \
# 6210             -0.533882            -0.581380
# 2054              1.398452             1.606551
# 5736             -0.622097            -0.663697
# 1875              0.948049             1.259203
# 3471             -0.078554            -0.514256
# ...                    ...                  ...
# 866               0.260733            -0.193689
# 2790              1.308060             1.574424
# 74                0.195229             0.359852
# 6320              0.669125             0.938331
# 338               0.191022             0.573005
#
#       Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number) (people suffering from depression)
# 6210                                          -0.253779
# 2054                                          -0.098963
# 5736                                          -0.109644
# 1875                                          -0.113570
# 3471                                          -0.229871
# ...                                                 ...
# 866                                           -0.224479
# 2790                                          -0.242777
# 74                                            -0.186718
# 6320                                           0.786586
# 338                                           -0.236638
#
# [5821 rows x 18 columns]
# [-0.53388248  1.39845214 -0.62209705 ...  0.19522919  0.66912489
#   0.19102165]
# (          Year  Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
#  6210  1.052274           0.073756             -1.703580             -0.856203
#  2054 -0.433289           1.061089              1.479617              1.822938
#  5736  1.299867           0.480834             -1.033922             -0.453273
#  1875  1.671258           1.228565              2.260584              1.978979
#  3471  1.671258          -1.290661             -0.658480             -0.883133
#
#        Anxiety disorders (%)  Drug use disorders (%)  \
#  6210              -0.664086               -0.400982
#  2054               2.370975                0.435030
#  5736              -0.572057               -0.128744
#  1875               0.466843                1.733763
#  3471              -0.281801               -0.766524
#
#        Alcohol use disorders (%)  20-24 years old (%)  10-14 years old (%)  \
#  6210                  -0.439776            -0.296644            -0.811821
#  2054                  -0.211459             1.233507             1.519230
#  5736                  -0.815803            -1.066898            -0.616607
#  1875                   0.239821             0.855871             0.950462
#  3471                   0.022277            -0.569719             0.066822
#
#        All ages (%)  70+ years old (%)  30-34 years old (%)  \
#  6210     -0.833572          -0.103029            -0.721169
#  2054      1.818524          -0.606332             1.525181
#  5736      0.471623           0.040691            -1.022095
#  1875      1.552777          -0.665968             1.293444
#  3471     -0.874479           0.978135            -0.469588
#
#        15-19 years old (%)  25-29 years old (%)  50-69 years old (%)  \
#  6210            -0.452162            -0.575913             0.136964
#  2054             0.990451             1.389302            -0.093999
#  5736            -0.779095            -1.131032             0.323636
#  1875             0.752761             1.150112            -0.232764
#  3471            -0.171268            -0.524436             0.633046
#
#        Age-standardized (%)  15-49 years old (%)  \
#  6210             -0.533882            -0.581380
#  2054              1.398452             1.606551
#  5736             -0.622097            -0.663697
#  1875              0.948049             1.259203
#  3471             -0.078554            -0.514256
#
#        Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number) (people suffering from depression)
#  6210                                          -0.253779
#  2054                                          -0.098963
#  5736                                          -0.109644
#  1875                                          -0.113570
#  3471                                          -0.229871                                                          ,
#  6210   -0.533882
#  2054    1.398452
#  5736   -0.622097
#  1875    0.948049
#  3471   -0.078554
#  Name: Depression (%), dtype: float64)

# %%
#Hyperparameter tuning to find the optimal parameters for the model
for i in [0.01,0.001,0.1]:
    for j in [10,100, 250, 500, 750]:
        gbt = GradientBoostingRegressor(learning_rate=i, n_estimators=j)
        gbt = gbt.fit(X_train, np_y_train)
        print("predict output for GradientBoostingRegressor: learning_rate={}, n_estimators={}".format(i, j))
        mse = mean_squared_error(np_y_test, gbt.predict(X_test))
        rmse = numpy.sqrt(mse)
        print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
        print("The root mean squared error (RMSE) on test set: {:.4f}".format(rmse))

        pred2 = gbt.predict(X_test)
        print("Accuracy on training set: %.3f" % gbt.score(X_train, np_y_train))
        print("Accuracy on test set: %.3f" % gbt.score(X_test, np_y_test))
        print("==============================================")
# Out:
# predict output for GradientBoostingRegressor: learning_rate=0.01, n_estimators=10
# The mean squared error (MSE) on test set: 0.7744
# The root mean squared error (RMSE) on test set: 0.8800
# Accuracy on training set: 0.176
# Accuracy on test set: 0.175
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.01, n_estimators=100
# The mean squared error (MSE) on test set: 0.1347
# The root mean squared error (RMSE) on test set: 0.3670
# Accuracy on training set: 0.854
# Accuracy on test set: 0.856
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.01, n_estimators=250
# The mean squared error (MSE) on test set: 0.0077
# The root mean squared error (RMSE) on test set: 0.0875
# Accuracy on training set: 0.992
# Accuracy on test set: 0.992
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.01, n_estimators=500
# The mean squared error (MSE) on test set: 0.0001
# The root mean squared error (RMSE) on test set: 0.0091
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.01, n_estimators=750
# The mean squared error (MSE) on test set: 0.0000
# The root mean squared error (RMSE) on test set: 0.0024
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.001, n_estimators=10
# The mean squared error (MSE) on test set: 0.9224
# The root mean squared error (RMSE) on test set: 0.9604
# Accuracy on training set: 0.019
# Accuracy on test set: 0.017
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.001, n_estimators=100
# The mean squared error (MSE) on test set: 0.7750
# The root mean squared error (RMSE) on test set: 0.8803
# Accuracy on training set: 0.175
# Accuracy on test set: 0.174
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.001, n_estimators=250
# The mean squared error (MSE) on test set: 0.5789
# The root mean squared error (RMSE) on test set: 0.7609
# Accuracy on training set: 0.381
# Accuracy on test set: 0.383
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.001, n_estimators=500
# The mean squared error (MSE) on test set: 0.3564
# The root mean squared error (RMSE) on test set: 0.5970
# Accuracy on training set: 0.617
# Accuracy on test set: 0.620
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.001, n_estimators=750
# The mean squared error (MSE) on test set: 0.2199
# The root mean squared error (RMSE) on test set: 0.4690
# Accuracy on training set: 0.762
# Accuracy on test set: 0.766
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.1, n_estimators=10
# The mean squared error (MSE) on test set: 0.1230
# The root mean squared error (RMSE) on test set: 0.3508
# Accuracy on training set: 0.866
# Accuracy on test set: 0.869
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.1, n_estimators=100
# The mean squared error (MSE) on test set: 0.0001
# The root mean squared error (RMSE) on test set: 0.0100
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.1, n_estimators=250
# The mean squared error (MSE) on test set: 0.0001
# The root mean squared error (RMSE) on test set: 0.0094
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000
# ==============================================
# predict output for GradientBoostingRegressor: learning_rate=0.1, n_estimators=500
# The mean squared error (MSE) on test set: 0.0001
# The root mean squared error (RMSE) on test set: 0.0090
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000
# ==============================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 5
#       3 for j in [10,100, 250, 500, 750]:
#       4     gbt = GradientBoostingRegressor(learning_rate=i, n_estimators=j)
# ----> 5     gbt = gbt.fit(X_train, np_y_train)
#       6     print("predict output for GradientBoostingRegressor: learning_rate={}, n_estimators={}".format(i, j))
#       7     mse = mean_squared_error(np_y_test, gbt.predict(X_test))
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:525, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     522     self._resize_state()
#     524 # fit the boosting stages
# --> 525 n_stages = self._fit_stages(
#     526     X,
#     527     y,
#     528     raw_predictions,
#     529     sample_weight,
#     530     self._rng,
#     531     X_val,
#     532     y_val,
#     533     sample_weight_val,
#     534     begin_at_stage,
#     535     monitor,
#     536 )
#     538 # change shape of arrays after fit (early-stopping or additional ests)
#     539 if n_stages != self.estimators_.shape[0]:
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:603, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     596         initial_loss = loss_(
#     597             y[~sample_mask],
#     598             raw_predictions[~sample_mask],
#     599             sample_weight[~sample_mask],
#     600         )
#     602 # fit next stage of trees
# --> 603 raw_predictions = self._fit_stage(
#     604     i,
#     605     X,
#     606     y,
#     607     raw_predictions,
#     608     sample_weight,
#     609     sample_mask,
#     610     random_state,
#     611     X_csc,
#     612     X_csr,
#     613 )
#     615 # track loss
#     616 if do_oob:
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:245, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     242     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     244 X = X_csr if X_csr is not None else X
# --> 245 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247 # update tree leaves
#     248 loss.update_terminal_regions(
#     249     tree.tree_,
#     250     X,
#    (...)
#     257     k=k,
#     258 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
gbt = GradientBoostingRegressor(learning_rate=0.1, n_estimators=10,random_state=42)

gbt = gbt.fit(X_train, np_y_train)
print("predict output for GradientBoostingRegressor: learning_rate={}, n_estimators={}".format(i, j))
mse = mean_squared_error(np_y_test, gbt.predict(X_test))
mae= mean_absolute_error(np_y_test, gbt.predict(X_test))
print("The root mean squared error (RMSE) on test set: {:.4f}".format(rmse))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
print("The mean absolute error (MAE) on test set: {:.4f}".format(mae))
pred2 = gbt.predict(X_test)
print("The best accuracy on training set: %.3f" % gbt.score(X_train, np_y_train))
print("The best accuracy on test set: %.3f" % gbt.score(X_test, np_y_test))
# Out:
# predict output for GradientBoostingRegressor: learning_rate=0.1, n_estimators=750
# The root mean squared error (RMSE) on test set: 0.0090
# The mean squared error (MSE) on test set: 0.1230
# The mean absolute error (MAE) on test set: 0.2721
# The best accuracy on training set: 0.866
# The best accuracy on test set: 0.869

# %%
param_distributions = {
    'learning_rate': uniform(0.01, 0.1),
    'n_estimators': randint(10, 750)
}

# Initialize the regressor
gbt = GradientBoostingRegressor(random_state=42)

# Initialize the Randomized Search model
random_search = RandomizedSearchCV(
    estimator=gbt,
    param_distributions=param_distributions,
    n_iter=50,  # Number of parameter settings that are sampled
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=0,
    verbose=1
)

# Fit the Randomized Search to the data
random_search.fit(X_train, y_train)

# Get the best parameters and corresponding mean squared error
best_params = random_search.best_params_
best_mse = -random_search.best_score_
best_rmse = mean_squared_error(y_test, random_search.predict(X_test), squared=False)

print(f"Best parameters: {best_params}")
print(f"Best RMSE: {best_rmse}")

# %%
y_pred = gbt.predict(X_test)

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.3)  # alpha is set for better visualization

# Plot a line representing the perfect predictions
plt.plot([-2, 2], [-2, 2], 'k--', lw=4)

# Set the limits of x and y axis
plt.xlim(-2, 2)
plt.ylim(-2, 2)

# Label the axes and title the plot
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Scatter Plot of Actual vs. Predicted Values')

# Show the plot
plt.show()

# %%
residuals = y_test - y_pred

# Plotting the residuals
plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, alpha=0.5)

# Plot a horizontal line at zero to show the point of no residual
plt.axhline(y=0, color='r', linestyle='--')

# Label the axes and title the plot
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals Plot')

# Show the plot
plt.show()

# %%
# Feature Importance
feature_importance = gbt.feature_importances_
indices = np.argsort(feature_importance)[::-1]
names = [X_train.columns[i] for i in indices]

# Plot the feature importances
plt.figure(figsize=(15, 5))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), feature_importance[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %%
feature_importance = gbt.feature_importances_
indices = np.argsort(feature_importance)[::-1]
names = [X_train.columns[i] for i in indices]

# Adding a small constant to feature importance to avoid log(0)
adjusted_importance = feature_importance + 1e-5

# Plot the feature importances with a log scale
plt.figure(figsize=(15, 5))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), np.log(adjusted_importance[indices]))
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.ylabel('Log of Importance Score')
plt.show()

# %%
#Linear Regression

import pandas as pd
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn import metrics

file_path =  'C:/Users/eashw/Downloads/Mental_health_Depression_disorder_Data.xlsx'

data = pd.read_excel(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head()

new_cols = [col for col in data.columns if col != 'Depression (%)'] + ['Depression (%)']
data = data[new_cols]
data = data.drop(columns=['Entity', 'Code'])
data.head()

X = pd.DataFrame(data.iloc[:, :-1]) #independent variable array
y = pd.DataFrame(data.iloc[:,-1]) #dependent variable vector

data.head()

# %%
X,y
# Out:
# (      Year  Schizophrenia (%)  Bipolar disorder (%)  Eating disorders (%)  \
#  0     1990           0.160560              0.697779              0.101855
#  1     1991           0.160312              0.697961              0.099313
#  2     1992           0.160135              0.698107              0.096692
#  3     1993           0.160037              0.698257              0.094336
#  4     1994           0.160022              0.698469              0.092439
#  ...    ...                ...                   ...                   ...
#  6463  2013           0.155670              0.607993              0.117248
#  6464  2014           0.155993              0.608610              0.118073
#  6465  2015           0.156465              0.609363              0.119470
#  6466  2016           0.157111              0.610234              0.121456
#  6467  2017           0.157963              0.611242              0.124443
#
#        Anxiety disorders (%)  Drug use disorders (%)  \
#  0                  4.828830                1.677082
#  1                  4.829740                1.684746
#  2                  4.831108                1.694334
#  3                  4.830864                1.705320
#  4                  4.829423                1.716069
#  ...                     ...                     ...
#  6463               3.090168                0.766280
#  6464               3.093964                0.768914
#  6465               3.098687                0.771802
#  6466               3.104294                0.772275
#  6467               3.110926                0.772648
#
#        Alcohol use disorders (%)  20-24 years old (%)  10-14 years old (%)  \
#  0                      0.672404             4.417802             1.594676
#  1                      0.671768             4.433524             1.588356
#  2                      0.670644             4.453689             1.577980
#  3                      0.669738             4.464517             1.577201
#  4                      0.669260             4.462960             1.570846
#  ...                         ...                  ...                  ...
#  6463                   1.515641             2.849725             1.057130
#  6464                   1.515470             2.856874             1.059057
#  6465                   1.514751             2.868684             1.062000
#  6466                   1.513269             2.893170             1.068818
#  6467                   1.510943             2.910070             1.073118
#
#        All ages (%)  70+ years old (%)  30-34 years old (%)  \
#  0         3.218871           5.202803             5.799034
#  1         3.203468           5.192849             5.814828
#  2         3.156559           5.176872             5.829745
#  3         3.120655           5.167355             5.853060
#  4         3.082179           5.157549             5.852851
#  ...            ...                ...                  ...
#  6463      2.304587           7.443744             3.224313
#  6464      2.326005           7.457945             3.243247
#  6465      2.352203           7.469626             3.267892
#  6466      2.383233           7.481952             3.295671
#  6467      2.415746           7.503119             3.323796
#
#        15-19 years old (%)  25-29 years old (%)  50-69 years old (%)  \
#  0                3.455708             5.175856             5.917752
#  1                3.451880             5.176729             5.927093
#  2                3.434982             5.160249             5.945656
#  3                3.420210             5.148767             5.966915
#  4                3.425222             5.148227             5.975907
#  ...                   ...                  ...                  ...
#  6463             2.360069             3.003961             5.680872
#  6464             2.367584             3.019263             5.707114
#  6465             2.375076             3.042733             5.728332
#  6466             2.382892             3.063618             5.764120
#  6467             2.393049             3.086543             5.790473
#
#        Age-standardized (%)  15-49 years old (%)  \
#  0                 4.071831             4.939766
#  1                 4.079531             4.902682
#  2                 4.088358             4.837097
#  3                 4.096190             4.813657
#  4                 4.099582             4.839340
#  ...                    ...                  ...
#  6463              3.128192             3.133858
#  6464              3.140290             3.153508
#  6465              3.155710             3.179233
#  6466              3.174134             3.206184
#  6467              3.192789             3.233777
#
#        Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number) (people suffering from depression)
#  0                                         318435.813670
#  1                                         329044.773956
#  2                                         382544.572895
#  3                                         440381.507393
#  4                                         456916.645489
#  ...                                                 ...
#  6463                                      303564.603590
#  6464                                      311665.769283
#  6465                                      320638.507158
#  6466                                      330437.353798
#  6467                                      340583.157405
#
#  [6468 rows x 18 columns],
#        Depression (%)
#  0           4.071831
#  1           4.079531
#  2           4.088358
#  3           4.096190
#  4           4.099582
#  ...              ...
#  6463        3.128192
#  6464        3.140290
#  6465        3.155710
#  6466        3.174134
#  6467        3.192789
#
#  [6468 rows x 1 columns])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
v = pd.DataFrame(regressor.coef_,index=['Co-efficient']).transpose()
w = pd.DataFrame(X.columns, columns=['Attribute'])

# %%
coeff_df = pd.concat([w,v], axis=1, join='inner')
coeff_df
# Out:
#                                             Attribute  Co-efficient
# 0                                                Year -4.567845e-16
# 1                                   Schizophrenia (%) -2.593369e-15
# 2                                Bipolar disorder (%) -5.289016e-16
# 3                                Eating disorders (%)  5.237508e-16
# 4                               Anxiety disorders (%)  1.942331e-16
# 5                              Drug use disorders (%)  1.011540e-16
# 6                           Alcohol use disorders (%)  8.005882e-17
# 7                                 20-24 years old (%) -2.674922e-17
# 8                                 10-14 years old (%) -4.073933e-17
# 9                                        All ages (%) -2.708321e-16
# 10                                  70+ years old (%) -5.016895e-17
# 11                                30-34 years old (%) -5.094219e-16
# 12                                15-19 years old (%) -3.326694e-17
# 13                                25-29 years old (%)  9.352453e-16
# 14                                50-69 years old (%)  1.015834e-16
# 15                               Age-standardized (%)  1.000000e+00
# 16                                15-49 years old (%)  2.194846e-16
# 17  Prevalence - Depressive disorders - Sex: Both ...  6.612827e-21

# %%
y_pred = regressor.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred
# Out:
#       Predicted
# 0      3.411459
# 1      3.707287
# 2      4.182413
# 3      3.372083
# 4      2.939887
# ...         ...
# 1289   3.713259
# 1290   3.707962
# 1291   3.681522
# 1292   2.831825
# 1293   3.392412
#
# [1294 rows x 1 columns]

# %%
print ('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print ('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred)) 
print ('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.140565616630619e-14
# Mean Squared Error: 1.0522720013838918e-26
# Root Mean Squared Error: 1.0258031006893535e-13

# %%
#create scatterplot with regression line and confidence interval lines
sns.regplot(x=y_test, y=y_pred)
# Out:
# <Axes: xlabel='Depression (%)', ylabel='Predicted'>

# %%
y_pred = gbt.predict(X_test)
r2 = r2_score(y_test, y_pred)

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.3)  # alpha is set for better visualization

# Plot a line representing the perfect predictions
plt.plot([-2, 2], [-2, 2], 'k--', lw=4)

# Set the limits of x and y axis
plt.xlim(-2, 2)
plt.ylim(-2, 2)

# Label the axes and title the plot
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Scatter Plot of Actual vs. Predicted Values')
plt.text(-1.5, 1.5, f'R-squared = {r2:.2f}', fontsize=12)

# Show the plot
plt.show()
